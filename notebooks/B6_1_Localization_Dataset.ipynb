# %% [markdown]
# # B6.1 — Coverage-correct localization dataset
#
# This CPU notebook reproduces the 14-layout B6.1 artifact. It uses exact KLayout `m1.2` edge pairs, 1600 nm contextual inputs, 160 nm halos, and non-overlapping 1280 nm supervised outputs. No model training or test-set inference occurs.

# %%
from google.colab import drive
drive.mount('/content/drive')

from pathlib import Path
PROJECT_DRIVE = Path('/content/drive/MyDrive/ADVLSI2 2026 Project')
EXPERIMENTS_ROOT = PROJECT_DRIVE / 'experiments'
DATASETS_ROOT = PROJECT_DRIVE / 'datasets'
B6_ROOT = EXPERIMENTS_ROOT / 'B6_localization'
DATASETS_ROOT.mkdir(parents=True, exist_ok=True)
B6_ROOT.mkdir(parents=True, exist_ok=True)
PROJECT_DRIVE

# %%
# !git clone https://github.com/nocleo/ADVLSI2_Project_updated.git
# %cd ADVLSI2_Project_updated
# !python -m pip install -q -r requirements.txt

# %%
# !python scripts/build_b6_localization_dataset.py

# %%
import json
from pathlib import Path
summary = json.loads(Path('results/b6_localization_dataset/summary.json').read_text())
assert summary['status'] == 'complete'
assert summary['layout_count'] == 14
assert summary['exact_violation_count'] == summary['unique_owner_count']
assert summary['dirty_tile_count'] == summary['clean_tile_count']
summary

# %%
import shutil
dataset_archive = Path('training_datasets/b6_localization_dataset.zip')
persistent_dataset = DATASETS_ROOT / dataset_archive.name
shutil.copy2(dataset_archive, persistent_dataset)
shutil.copytree(
    Path('results/b6_localization_dataset'),
    B6_ROOT / 'b6_localization_dataset_summary',
    dirs_exist_ok=True,
)
print(f'Persistent dataset: {persistent_dataset}')
print(f'Persistent summary: {B6_ROOT / "b6_localization_dataset_summary"}')
